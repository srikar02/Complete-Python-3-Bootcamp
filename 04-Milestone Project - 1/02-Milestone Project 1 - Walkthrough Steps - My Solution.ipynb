# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Milestone Project 1: Walkthrough Steps Workbook
#
# Below is a set of steps for you to follow to try to create the Tic Tac Toe Milestone Project game!

# %% [markdown]
# #### Some suggested tools before you get started:
# To take input from a user:
#
#     player1 = input("Please pick a marker 'X' or 'O'")
#
# Note that input() takes in a string. If you need an integer value, use
#
#     position = int(input('Please enter a number'))
#
# <br>To clear the screen between moves:
#
#     from IPython.display import clear_output
#     clear_output()
#
# Note that clear_output() will only work in jupyter. To clear the screen in other IDEs, consider:
#
#     print('\n'*100)
#
# This scrolls the previous board up out of view. Now on to the program!

# %% [markdown]
# **Step 1: Write a function that can print out a board. Set up your board as a list, where each index 1-9 corresponds with a number on a number pad, so you get a 3 by 3 board representation.**

# %%
from IPython.display import clear_output

def display_board(board):
    clear_output()
    for index in range(1,4):
        print(board[index], end = '\t')
    print('\n----------------')
    for index in range(4,7):
        print(board[index], end = '\t')
    print('\n----------------')
    for index in range(7,len(board)):
        print(board[index], end = '\t')

# %% [markdown]
# **TEST Step 1:** run your function on a test version of the board list, and make adjustments as necessary

# %%
test_board = ['#','X','O','X','O','X','O','X','O','X']
display_board(test_board)
# Out:
# X	O	X
# ----------------
# O	X	O
# ----------------
# X	O	X

# %%
test_board = ['#','O','O','X','X','X','O','X','X','X']
display_board(test_board)
# Out:
# O	O	X
# ----------------
# X	X	O
# ----------------
# X	X	X

# %% [markdown]
# **Step 2: Write a function that can take in a player input and assign their marker as 'X' or 'O'. Think about using *while* loops to continually ask until you get a correct answer.**

# %%
def player_input():
    while(True):
        player_input_value = input('Enter your choice (X or O): ')
        if(player_input_value == 'X' or player_input_value == 'O'):
            print('Playing with {}'.format(player_input_value))
            break
        else:
            print('Incorrect input {}'.format(player_input_value))
    return player_input_value

# %% [markdown]
# **TEST Step 2:** run the function to make sure it returns the desired output

# %%
player_input()
# Out:
# Enter your choice (X or O): O
# Playing with O
# 'O'

# %% [markdown]
# **Step 3: Write a function that takes in the board list object, a marker ('X' or 'O'), and a desired position (number 1-9) and assigns it to the board.**

# %%
def place_marker(board, marker, position):
    board[position] = marker

# %% [markdown]
# **TEST Step 3:** run the place marker function using test parameters and display the modified board

# %%
place_marker(test_board,'$',8)
display_board(test_board)
# Out:
# O	O	X
# ----------------
# X	X	O
# ----------------
# X	$	X

# %%
place_marker(test_board,'%',3)
display_board(test_board)
# Out:
# O	O	%
# ----------------
# X	X	O
# ----------------
# X	$	X

# %% [markdown]
# **Step 4: Write a function that takes in a board and a mark (X or O) and then checks to see if that mark has won. **

# %%
def win_check(board, mark):
    return all(ele == mark for ele in board[1:4:1]) or \
all(ele == mark for ele in board[1:4:1]) or \
all(ele == mark for ele in board[4:7:1]) or \
all(ele == mark for ele in board[7:10:1]) or\
all(ele == mark for ele in board[1:8:3]) or\
all(ele == mark for ele in board[2:9:3]) or\
all(ele == mark for ele in board[3:10:3]) or\
all(ele == mark for ele in board[1:10:4]) or\
all(ele == mark for ele in board[3:8:2])

#     print(board[1:4:1])
#     print(board[4:7:1])
#     print(board[7:10:1])
#     print(board[1:8:3])
#     print(board[2:9:3])
#     print(board[3:10:3])
#     print(board[1:10:4])
#     print(board[3:8:2])

# %% [markdown]
# **TEST Step 4:** run the win_check function against our test_board - it should return True

# %%
win_check(test_board,'X')
# Out:
# False

# %%
win_check(test_board,'O')
# Out:
# False

# %% [markdown]
# **Step 5: Write a function that uses the random module to randomly decide which player goes first. You may want to lookup random.randint() Return a string of which player went first.**

# %%
import random

def choose_first():
    result = random.randint(1,2)
    if result == 1:
        print('Player 1 goes first')
        return 'Player 1'
    else:
        print('Player 2 goes first')
        return 'Player 2'

# %%
choose_first()
# Out:
# Player 2 goes first
# 'Player 2'

# %% [markdown]
# **Step 6: Write a function that returns a boolean indicating whether a space on the board is freely available.**

# %%
def space_check(board, position):
    return board[position] == ''

# %%
test_board = ['#','X','O','X','O','X','O','X','O','X']
space_check(test_board,4)
# Out:
# False

# %% [markdown]
# **Step 7: Write a function that checks if the board is full and returns a boolean value. True if full, False otherwise.**

# %%
def full_board_check(board):
    return all(element != '' for element in board)

# %%
test_board = ['#','X','O','X','O','X','O','X','O','X']
full_board_check(test_board)
# Out:
# True

# %%
test_board = ['#','X','','','','O','','','','X']
full_board_check(test_board)
# Out:
# False

# %% [markdown]
# **Step 8: Write a function that asks for a player's next position (as a number 1-9) and then uses the function from step 6 to check if it's a free position. If it is, then return the position for later use.**

# %%
def player_choice(board):
    while True:
        position = input('Enter position (1-9): ')
        if (space_check(board, int(position))):
            print('Using position {}'.format(position))
            return int(position)
        else:
            print('Position already taken, try a different one')

# %%
test_board = ['#','X','O','X','O','X','O','','O','X']
player_choice(test_board)
# Out:
# Enter position (1-9): 7
# Using position 7
# 7

# %% [markdown]
# **Step 9: Write a function that asks the player if they want to play again and returns a boolean True if they do want to play again.**

# %%
def replay():
    play_again = input('Would you like to play again (y or n)? ')
    return play_again == 'y'

# %% [markdown]
# **Step 10: Here comes the hard part! Use while loops and the functions you've made to run the game!**

# %%
print('Welcome to Tic Tac Toe!')
while True:
    test_board = ['#','','','','','','','','','']
    print('Initial Board')
    display_board(test_board)
    
    first_player = choose_first()
    first_player_input = player_input()
    
    second_player = ''
    second_player_input = ''
    
    if(first_player == 'Player 1'):
        second_player = 'Player 2'
    else:
        second_player = 'Player 1'
    
    if(first_player_input == 'X'):
        second_player_input = 'O'
    else:
        second_player_input = 'X'
        
    print('{} playing with {}'.format(first_player,first_player_input))
    print('{} playing with {}'.format(second_player,second_player_input))
    
    game_on = True
    while game_on:
        print('{} playing'.format(first_player))
        first_player_choice = player_choice(test_board)
        place_marker(test_board, first_player_input, first_player_choice)
        display_board(test_board)
        if(win_check(test_board, first_player_input)):
            display_board(test_board)
            print('{} player won'.format(first_player))
            game_on = False
            break
        elif(full_board_check(test_board)):
            display_board(test_board)
            print('Board Full')
            game_on = False
            break
            
        print('{} playing'.format(second_player))
        second_player_choice = player_choice(test_board)
        place_marker(test_board, second_player_input, second_player_choice)
        display_board(test_board)
        if(win_check(test_board, second_player_input)):
            display_board(test_board)
            print('{} player won'.format(second_player))
            game_on = False
            break
        elif(full_board_check(test_board)):
            display_board(test_board)
            print('Board Full')
            game_on = False
            break
        
    if not replay():
        break
    # Set the game up here
    #pass

    #while game_on:
        #Player 1 Turn
        
        
        # Player2's turn.
            
            #pass

    #if not replay():
    #    break
# Out:
# X	O	X
# ----------------
# O	O	X
# ----------------
# O	X	O	Board Full
# Would you like to play again (y or n)? n

# %% [markdown]
# ## Good Job!
